# %% [markdown]
# #### Ryan Gilbert
# #### July 17th, 2025
# #### Project 1, Part 2: Data Exploration
# #### Objective: Explore the Project 1 dataset using Python, and perform data cleaning using pandas.

# %%
import pandas as pd
import numpy as np

# %%
df_Fall_2020 = pd.read_csv("Majors Survey Results - Fall 2020.csv")

# %% [markdown]
# ### Running some basic exploratory functions to get an idea of what the data collected includes and how it looks

# %%
df_Fall_2020.head()
# Out:
#                     Timestamp   Which course are you enrolled in?  \
# 0   2020/07/28 3:21:36 PM EST  CMP 239 Internet & Web Page Design
# 1   2020/07/28 4:07:22 PM EST  CMP 239 Internet & Web Page Design
# 2   2020/07/28 8:12:47 PM EST  CMP 239 Internet & Web Page Design
# 3  2020/07/29 10:53:03 AM EST  CMP 239 Internet & Web Page Design
# 4   2020/07/29 4:26:21 PM EST  CMP 239 Internet & Web Page Design
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %%
df_Fall_2020.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?
# count                                          90.000000
# mean                                            3.400000
# std                                             1.159233
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# #### Getting a list of the names of all of the columns found in this data set

# %%
df_Fall_2020.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### Finding out the total number of rows and columns in the data frame.

# %%
df_Fall_2020.shape
# Out:
# (298, 79)

# %% [markdown]
# ### Exploring the data types of each of the different columns in the Fall 2020 dataset.

# %%
df_Fall_2020.dtypes
# Out:
# Timestamp                                                                                                                                               object
# Which course are you enrolled in?                                                                                                                       object
# How did you hear about County College of Morris? [CCM Web site]                                                                                         object
# How did you hear about County College of Morris? [Social Media]                                                                                         object
# How did you hear about County College of Morris? [Community Event]                                                                                      object
#                                                                                                                                                         ...
# ...

# %%
df_Fall_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 79 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        298 non-null    object
# ...

# %%
df_Fall_2020.sample()
# Out:
#                      Timestamp Which course are you enrolled in?  \
# 261  2020/09/24 6:52:46 PM EST        CMP 128 Computer Science I
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 261                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 261                                                 No
#
#     How did you hear about County College of Morris? [Community Event]  \
# 261                                                 No
#
#     How did you hear about County College of Morris? [Family member or friend]  \
# 261                                                Yes
#
#     How did you hear about County College of Morris? [Current CCM student]  \
# 261                                                Yes
#
#     How did you hear about County College of Morris? [CCM Alumni]  \
# 261                                                 No
#
# ...

# %% [markdown]
# ### Checking to see how many missing values there are in the data-set and which questions have those values.

# %%
missing_values = df_Fall_2020.isnull().sum()[df_Fall_2020.isnull().sum() > 0]

# %%
missing_values
# Out:
# To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]                                                                                                                             22
# To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]                                                                                                                        15
# To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]                                                                                                                          11
# To what extent did the following impact your decision to attend County College of Morris? [Online offerings]                                                                                                                            32
# ...

# %% [markdown]
# ### Confirming if there are any duplicate records in this data set

# %%
duplicates_2020 = df_Fall_2020.duplicated()

# %%
any(duplicates_2020)
# Out:
# False

# %% [markdown]
# ### Finding out that there are any differences from Fall 2024 from the Fall 2020 set

# %% [markdown]
# ##### There are different numbers of rows (expected) and columns (unexpected).
# ##### There are additional questions in this set

# %%
df_Fall_2024 = pd.read_csv("Majors Survey Results - Fall 2024.csv")

# %%
df_Fall_2024.shape
# Out:
# (197, 90)

# %% [markdown]
# ### There are a different number of rows (expected) and columns (unexpected) from the Fall 2024 data set.

# %% [markdown]
# ##### There are no duplicates in this data set either.

# %%
duplicates_2024 = df_Fall_2024.duplicated()

# %%
any(duplicates_2024)
# Out:
# False

# %% [markdown]
# ### Checking to confirm if there are missing values in this data set as well.

# %%
missing_values_2024 = df_Fall_2024.isnull().sum()[df_Fall_2024.isnull().sum() > 0]

# %%
missing_values_2024
# Out:
# Which course are you enrolled in?                                                                                                                                                                                                        2
# To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]                                                                                                                              5
# To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]                                                                                                                         5
# To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]                                                                                                                           5
# ...
